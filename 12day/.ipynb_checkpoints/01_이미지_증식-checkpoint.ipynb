# %%
"""
<이미지 증식>
 - 이미지 분석 시 많은 양의 데이터 확보가 필요한 경우 직접 이미지 생성
 - 특정 원본 이미지를 기준으로 여러 형태로 변형 -> 이미지를 새롭게 생선하는 방법
 - 사용 패키지 : keras.preprocessing.image
 - 사용 라이브러리 : ImageDataGenerator

<이미지 증식 순서>
 - 증식에 사용할 원본 이미지 파일 릭어들이기
 - 읽어 들인 이미지 파일에서 이미지 데이터 추출
 - 이미지 생성 클래스 생성 및 설정
 - 이미지 생성을 위한 함수 정의 flow() 및 변형할 형태 설정
"""

# %%
# 텐서플로우 프레임워크
import tensorflow as tf

# 케라스(딥러닝 모델) 라이브러리
from tensorflow import keras

# 시각화 라이브러리
import matplotlib.pyplot as plt

# 넘파이
import numpy as np

# 데이터 분류 라이브러리
from sklearn.model_selection import train_test_split

import pandas as pd

# 딥러닝 랜덤규칙 정의(모든 사람이 정확하게 일치하지는 않음)
tf.keras.utils.set_random_seed(42)
tf.config.experimental.enable_op_determinism()

# %%
from keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img

# %%
img = load_img("./img/1-1.png")
img
# Out:
# <PIL.Image.Image image mode=RGB size=1000x628>

# %%
x = img_to_array(img)
x
# Out:
# array([[[187., 190., 197.],
#         [188., 191., 198.],
#         [188., 191., 198.],
#         ...,
#         [189., 192., 199.],
#         [190., 193., 200.],
#         [189., 192., 199.]],
#
#        [[187., 190., 197.],
#         [187., 190., 197.],
#         [187., 190., 197.],
#         ...,
#         [188., 191., 198.],
#         [188., 191., 198.],
#         [189., 192., 199.]],
#
#        [[187., 190., 197.],
#         [186., 189., 196.],
#         [187., 190., 197.],
#         ...,
#         [189., 192., 199.],
#         [189., 192., 199.],
#         [189., 192., 199.]],
#
#        ...,
#
#        [[205., 142.,  91.],
#         [208., 142.,  90.],
#         [211., 144.,  92.],
#         ...,
#         [216., 176., 140.],
#         [216., 176., 140.],
#         [217., 178., 144.]],
#
#        [[206., 142.,  91.],
#         [208., 142.,  91.],
#         [210., 145.,  93.],
#         ...,
#         [217., 177., 141.],
#         [217., 177., 141.],
# ...

# %%
x.reshape((1, ) + x.shape)
# Out:
# array([[[[187., 190., 197.],
#          [188., 191., 198.],
#          [188., 191., 198.],
#          ...,
#          [189., 192., 199.],
#          [190., 193., 200.],
#          [189., 192., 199.]],
#
#         [[187., 190., 197.],
#          [187., 190., 197.],
#          [187., 190., 197.],
#          ...,
#          [188., 191., 198.],
#          [188., 191., 198.],
#          [189., 192., 199.]],
#
#         [[187., 190., 197.],
#          [186., 189., 196.],
#          [187., 190., 197.],
#          ...,
#          [189., 192., 199.],
#          [189., 192., 199.],
#          [189., 192., 199.]],
#
#         ...,
#
#         [[205., 142.,  91.],
#          [208., 142.,  90.],
#          [211., 144.,  92.],
#          ...,
#          [216., 176., 140.],
#          [216., 176., 140.],
#          [217., 178., 144.]],
#
#         [[206., 142.,  91.],
#          [208., 142.,  91.],
#          [210., 145.,  93.],
#          ...,
#          [217., 177., 141.],
# ...

# %%
imgGen = ImageDataGenerator(
    rescale=1. /255,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.5,
    zoom_range=[0.8, 2.0],
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode="nearest"
)
