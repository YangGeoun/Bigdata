# %%
import pandas as pd
import numpy as np
from scipy.stats import spearmanr, pearsonr
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
### 시각화를 위한 라이브러리
# - 파이썬 시각화에서 가장 기본적인 시각화 라이브러리
import matplotlib.pyplot as plt

### 한글처리
from matplotlib import font_manager, rc

### 운영체제 확인 라이브러리
import platform

### 시각화 시 마이너스(-, 음수) 기호 깨짐 방지
plt.rcParams["axes.unicode_minus"] = False

### OS별 한글처리
# - 윈도우 운영체게
if platform.system() == "Windows" :
    # path = "c:/Windows/Fonts/malgun.ttf"
    # font_name = font_manager.FontProperties(fname=path).get_name()
    # rc("font", family = font_name)
    
    ### 또는 아래처럼 한줄로도 가능 (아래 한글처리를 주로 사용합니다.)
    plt.rc("font", family = "Malgun Gothic")

# - Mac 운영체제
elif platform.system() == "Darwin" :
    rc("font", family = "AppleGothic")
    
else :
    print("넌 누구?")

# %%
labeled = pd.read_csv("./data/labeled_data.csv")
labeled_cn7 = labeled[(labeled["PART_NAME"] == "CN7 W/S SIDE MLD'G RH") |(labeled["PART_NAME"] == "CN7 W/S SIDE MLD'G LH")]
labeled_cn7 = labeled_cn7.drop(columns=["_id", "TimeStamp","PART_FACT_PLAN_DATE", "Reason", "PART_FACT_SERIAL", "PART_NAME",
               "EQUIP_NAME", "EQUIP_CD", "Switch_Over_Position", "Mold_Temperature_1","Mold_Temperature_2","Mold_Temperature_5",
                "Mold_Temperature_6", "Mold_Temperature_7","Mold_Temperature_8","Mold_Temperature_9","Mold_Temperature_10",
               "Mold_Temperature_11","Mold_Temperature_12","Barrel_Temperature_7"])
labeled_cn7
# Out:
#      PassOrFail  Injection_Time  Filling_Time  Plasticizing_Time  Cycle_Time  \
# 0             Y            9.59          4.47          16.920000   59.520000
# 1             Y            9.60          4.48          16.910000   59.580002
# 2             Y            9.60          4.48          16.910000   59.580002
# 3             Y            9.59          4.48          16.910000   59.560001
# 4             Y            9.59          4.48          16.910000   59.560001
# ...         ...             ...           ...                ...         ...
# 7991          Y            9.60          4.48          16.620001   59.560001
# 7992          Y            9.60          4.48          16.650000   59.560001
# 7993          Y            9.60          4.48          16.650000   59.560001
# 7994          Y            9.60          4.48          16.629999   59.580002
# 7995          Y            9.60          4.48          16.629999   59.580002
#
#       Clamp_Close_Time  Cushion_Position  Plasticizing_Position  \
# 0                 7.13        653.409973              68.849998
# 1                 7.13        653.409973              68.839996
# 2                 7.13        653.409973              68.839996
# 3                 7.13        653.419983              68.839996
# 4                 7.13        653.419983              68.839996
# ...                ...               ...                    ...
# 7991              7.11        653.429993              68.330002
# 7992              7.11        653.429993              68.349998
# 7993              7.11        653.429993              68.349998
# 7994              7.11        653.429993              68.330002
# 7995              7.11        653.429993              68.330002
#
#       Clamp_Open_Position  Max_Injection_Speed  ...  Average_Back_Pressure  \
# 0               647.98999            55.400002  ...              59.299999
# 1               647.98999            55.299999  ...              59.299999
# 2               647.98999            55.299999  ...              59.299999
# 3               647.98999            55.299999  ...              59.299999
# 4               647.98999            55.299999  ...              59.299999
# ...                   ...                  ...  ...                    ...
# 7991            647.98999            54.900002  ...              59.900002
# 7992            647.98999            55.000000  ...              59.900002
# 7993            647.98999            55.000000  ...              59.900002
# 7994            647.98999            54.900002  ...              59.900002
# 7995            647.98999            54.900002  ...              59.900002
#
#       Barrel_Temperature_1  Barrel_Temperature_2  Barrel_Temperature_3  \
# 0               276.500000            274.700012            274.799988
# 1               276.200012            275.500000            275.299988
# 2               276.200012            275.500000            275.299988
# 3               276.500000            275.000000            275.399994
# 4               276.500000            275.000000            275.399994
# ...                    ...                   ...                   ...
# 7991            276.500000            274.899994            275.100006
# 7992            275.799988            275.299988            275.500000
# 7993            275.799988            275.299988            275.500000
# 7994            276.100006            275.799988            275.000000
# 7995            276.100006            275.799988            275.000000
#
#       Barrel_Temperature_4  Barrel_Temperature_5  Barrel_Temperature_6  \
# 0               269.200012            255.000000            229.699997
# 1               270.799988            254.699997            229.500000
# 2               270.799988            254.699997            229.500000
# 3               271.100006            254.899994            230.000000
# 4               271.100006            254.899994            230.000000
# ...                    ...                   ...                   ...
# 7991            269.500000            255.600006            229.600006
# 7992            270.700012            254.899994            230.000000
# 7993            270.700012            254.899994            230.000000
# 7994            271.299988            255.100006            230.199997
# 7995            271.299988            255.100006            230.199997
#
#       Hopper_Temperature  Mold_Temperature_3  Mold_Temperature_4
# 0              66.300003           24.799999           27.500000
# 1              67.199997           24.799999           27.600000
# 2              67.199997           24.799999           27.600000
# 3              66.900002           25.000000           27.600000
# 4              66.900002           25.000000           27.600000
# ...                  ...                 ...                 ...
# 7991           66.099998           21.000000           22.400000
# 7992           66.099998           21.000000           22.400000
# 7993           66.099998           21.000000           22.400000
# 7994           65.199997           21.000000           22.299999
# 7995           65.199997           21.000000           22.299999
#
# [6736 rows x 25 columns]

# %%
labeled_cn7["PassOrFail"] = labeled_cn7["PassOrFail"].replace('Y',1).replace('N',0)
### Clamp_Open_Position에서 눈에띄게 낮은 값들 제거
cn7 = labeled_cn7[labeled_cn7["Clamp_Open_Position"]>=200] 
cn7 = cn7.drop(columns=["Clamp_Open_Position"])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_19684\1946031374.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   labeled_cn7["PassOrFail"] = labeled_cn7["PassOrFail"].replace('Y',1).replace('N',0)

# %%
def remove_outliers(df, column):
    # 1사분위수(Q1)와 3사분위수(Q3) 계산
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    
    # IQR 계산
    IQR = Q3 - Q1
    
    # 이상치 범위 설정
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # 이상치 제거
    filtered_df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    
    return filtered_df

# %%
cn7_Y = cn7[cn7["PassOrFail"]==1].copy()
print("CN7의 양품 개수:", len(cn7_Y))
cn7_N = cn7[cn7["PassOrFail"]==0].copy()
print("CN7의 불량 개수:", len(cn7_N))

tmp1 = cn7_Y.copy()
tmp1 = remove_outliers(tmp1, "Injection_Time")
tmp1 = remove_outliers(tmp1, "Plasticizing_Time")
tmp1 = remove_outliers(tmp1, "Cycle_Time")
tmp1 = remove_outliers(tmp1, "Max_Injection_Speed")
tmp1 = remove_outliers(tmp1, "Mold_Temperature_3")
cn7_pass_removed = tmp1.copy()
cn7_pass_removed.info()
# Out:
# CN7의 양품 개수: 6661
# CN7의 불량 개수: 39
# <class 'pandas.core.frame.DataFrame'>
# Index: 6534 entries, 0 to 7995
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   PassOrFail                6534 non-null   int64
#  1   Injection_Time            6534 non-null   float64
#  2   Filling_Time              6534 non-null   float64
#  3   Plasticizing_Time         6534 non-null   float64
#  4   Cycle_Time                6534 non-null   float64
#  5   Clamp_Close_Time          6534 non-null   float64
#  6   Cushion_Position          6534 non-null   float64
#  7   Plasticizing_Position     6534 non-null   float64
#  8   Max_Injection_Speed       6534 non-null   float64
#  9   Max_Screw_RPM             6534 non-null   float64
#  10  Average_Screw_RPM         6534 non-null   float64
#  11  Max_Injection_Pressure    6534 non-null   float64
#  12  Max_Switch_Over_Pressure  6534 non-null   float64
#  13  Max_Back_Pressure         6534 non-null   float64
#  14  Average_Back_Pressure     6534 non-null   float64
#  15  Barrel_Temperature_1      6534 non-null   float64
#  16  Barrel_Temperature_2      6534 non-null   float64
#  17  Barrel_Temperature_3      6534 non-null   float64
#  18  Barrel_Temperature_4      6534 non-null   float64
#  19  Barrel_Temperature_5      6534 non-null   float64
#  20  Barrel_Temperature_6      6534 non-null   float64
#  21  Hopper_Temperature        6534 non-null   float64
#  22  Mold_Temperature_3        6534 non-null   float64
#  23  Mold_Temperature_4        6534 non-null   float64
# dtypes: float64(23), int64(1)
# memory usage: 1.2 MB

# %%
cn7_removed = pd.concat([cn7_pass_removed, cn7_N], ignore_index=True)
cn7_removed["PassOrFail"].value_counts()
# Out:
# PassOrFail
# 1    6534
# 0      39
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# 독립변수 종속변수 분리 
y = cn7_removed["PassOrFail"]
X = cn7_removed.drop(columns=["PassOrFail"])

# 테스트 데이터 분리
X_train, X_test, y_train, y_test  = train_test_split(X, y, test_size=0.3, random_state=42)

# 검증 데이터 분리
X_train, X_val, y_train, y_val  = train_test_split(X_train, y_train, test_size=0.3, random_state=42)

# 데이터 정규화
ss=StandardScaler()
ss.fit(X_train)
X_train_scaled = ss.transform(X_train)
X_val_scaled = ss.transform(X_val)
X_test_scaled=ss.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
model = Sequential()
model.add(Dense(units=64 , activation="relu"))
model.add(Dense(units=128 , activation="relu"))
model.add(Dropout(0.25))
model.add(Dense(units=64 , activation="relu"))
model.add(Dropout(0.25))
model.add(Dense(units=32 , activation="relu"))
model.add(Dense(units=1 , activation="sigmoid"))
model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy', 
                                                                    tf.keras.metrics.Precision(name="precision"),
                                                                    tf.keras.metrics.Recall(name="recall")])

# %%
model.fit(X_train_scaled, y_train, epochs=40, validation_split=0.3)
# Out:
# Epoch 1/40
# 71/71 [==============================] - 1s 8ms/step - loss: 0.1595 - accuracy: 0.9805 - precision: 0.9973 - recall: 0.9831 - val_loss: 0.1858 - val_accuracy: 0.9928 - val_precision: 0.9928 - val_recall: 1.0000
# Epoch 2/40
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0580 - accuracy: 0.9973 - precision: 0.9973 - recall: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9928 - val_precision: 0.9928 - val_recall: 1.0000
# Epoch 3/40
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0233 - accuracy: 0.9973 - precision: 0.9973 - recall: 1.0000 - val_loss: 0.1615 - val_accuracy: 0.9928 - val_precision: 0.9928 - val_recall: 1.0000
# Epoch 4/40
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 0.9978 - precision: 0.9978 - recall: 1.0000 - val_loss: 0.1618 - val_accuracy: 0.9938 - val_precision: 0.9938 - val_recall: 1.0000
# Epoch 5/40
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0046 - accuracy: 0.9991 - precision: 0.9991 - recall: 1.0000 - val_loss: 0.1750 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 6/40
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 0.9996 - precision: 0.9996 - recall: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 7/40
# 71/71 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 0.9996 - precision: 0.9996 - recall: 1.0000 - val_loss: 0.1994 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 8/40
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.9996 - precision: 0.9996 - recall: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 9/40
# 71/71 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 0.9996 - precision: 0.9996 - recall: 1.0000 - val_loss: 0.2177 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 10/40
# 71/71 [==============================] - 0s 2ms/step - loss: 6.6740e-04 - accuracy: 0.9996 - precision: 0.9996 - recall: 1.0000 - val_loss: 0.2315 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 11/40
# 71/71 [==============================] - 0s 2ms/step - loss: 7.8784e-04 - accuracy: 0.9996 - precision: 0.9996 - recall: 1.0000 - val_loss: 0.2402 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 12/40
# 71/71 [==============================] - 0s 2ms/step - loss: 3.8362e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2464 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 13/40
# 71/71 [==============================] - 0s 2ms/step - loss: 4.0885e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2532 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 14/40
# 71/71 [==============================] - 0s 2ms/step - loss: 6.7867e-04 - accuracy: 0.9996 - precision: 0.9996 - recall: 1.0000 - val_loss: 0.2578 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 15/40
# 71/71 [==============================] - 0s 2ms/step - loss: 2.5191e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 16/40
# 71/71 [==============================] - 0s 2ms/step - loss: 3.6257e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2660 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 17/40
# 71/71 [==============================] - 0s 2ms/step - loss: 2.2466e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2723 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 18/40
# 71/71 [==============================] - 0s 2ms/step - loss: 1.0697e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2772 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 19/40
# 71/71 [==============================] - 0s 2ms/step - loss: 8.7672e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2805 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 20/40
# 71/71 [==============================] - 0s 2ms/step - loss: 1.3689e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2855 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 21/40
# 71/71 [==============================] - 0s 2ms/step - loss: 5.7417e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2892 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 22/40
# 71/71 [==============================] - 0s 2ms/step - loss: 8.4688e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2941 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 23/40
# 71/71 [==============================] - 0s 2ms/step - loss: 3.5612e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.2980 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 24/40
# 71/71 [==============================] - 0s 2ms/step - loss: 8.2291e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3005 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 25/40
# 71/71 [==============================] - 0s 2ms/step - loss: 4.5737e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3037 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 26/40
# 71/71 [==============================] - 0s 2ms/step - loss: 9.4616e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3066 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 27/40
# 71/71 [==============================] - 0s 2ms/step - loss: 4.8354e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3092 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 28/40
# 71/71 [==============================] - 0s 2ms/step - loss: 2.4389e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3131 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 29/40
# 71/71 [==============================] - 0s 2ms/step - loss: 1.4243e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3162 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 30/40
# 71/71 [==============================] - 0s 2ms/step - loss: 1.8099e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3189 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 31/40
# 71/71 [==============================] - 0s 2ms/step - loss: 1.3549e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3216 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 32/40
# 71/71 [==============================] - 0s 2ms/step - loss: 7.3869e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3239 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 33/40
# 71/71 [==============================] - 0s 2ms/step - loss: 1.0974e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3262 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 34/40
# 71/71 [==============================] - 0s 2ms/step - loss: 1.0732e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3277 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 35/40
# 71/71 [==============================] - 0s 2ms/step - loss: 1.4625e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3305 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 36/40
# 71/71 [==============================] - 0s 2ms/step - loss: 7.5762e-06 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3329 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 37/40
# 71/71 [==============================] - 0s 2ms/step - loss: 1.6095e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3349 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 38/40
# 71/71 [==============================] - 0s 2ms/step - loss: 6.8175e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3293 - val_accuracy: 0.9938 - val_precision: 0.9948 - val_recall: 0.9990
# Epoch 39/40
# 71/71 [==============================] - 0s 2ms/step - loss: 2.5388e-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - val_loss: 0.3352 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000
# Epoch 40/40
# 71/71 [==============================] - 0s 2ms/step - loss: 8.1388e-04 - accuracy: 0.9991 - precision: 0.9996 - recall: 0.9996 - val_loss: 0.3653 - val_accuracy: 0.9948 - val_precision: 0.9948 - val_recall: 1.0000

# %%
prob = model.predict(X_test_scaled)

# %%
y_pred = list(map(lambda x: 1 if x[0] > 0.70 else 0, prob))

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_test, y_pred))
cm = confusion_matrix(y_test, y_pred)
cm_df = pd.DataFrame(cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])
print("혼돈 행렬:")
print(cm_df)
print("\n")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.57      0.73        14
#            1       1.00      1.00      1.00      1958
#
#     accuracy                           1.00      1972
#    macro avg       1.00      0.79      0.86      1972
# weighted avg       1.00      1.00      1.00      1972
#
# 혼돈 행렬:
#           Predicted 0  Predicted 1
# Actual 0            8            6
# Actual 1            0         1958
