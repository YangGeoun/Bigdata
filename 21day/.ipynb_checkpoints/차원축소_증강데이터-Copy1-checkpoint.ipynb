# %%
import pandas as pd

# %%
cn7 = pd.read_csv("./cn7_resampled.csv")

# %%
from sklearn.model_selection import train_test_split
y = cn7["PassOrFail"]
X = cn7.drop(columns=["PassOrFail"])
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=42)

test_data = pd.read_csv("./cn7_test.csv")
y_test = test_data["PassOrFail"]
X_test = test_data.drop(columns=["PassOrFail"])

# %%
# from sklearn.preprocessing import StandardScaler
# ss=StandardScaler()
# ss.fit(X_train)
# X_train_scaled = ss.transform(X_train)
# X_val_scaled = ss.transform(X_val)
# X_test_scaled=ss.transform(X_test)

# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import precision_score, accuracy_score, recall_score, f1_score, confusion_matrix
# from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, HistGradientBoostingClassifier, GradientBoostingClassifier
# from xgboost import XGBClassifier
# # 모델 생성
# rf = RandomForestClassifier(random_state=42)
# et = ExtraTreesClassifier(random_state=42)
# gb = GradientBoostingClassifier(random_state=42)
# hgb = HistGradientBoostingClassifier(random_state=42)
# xgb = XGBClassifier(random_state=42)
# model_list = [rf, et, gb, hgb, xgb]

# grid_df = pd.DataFrame()

# # GridSearchCV 이용해서 모든 모델 하이퍼파라미터 튜닝
# for model in model_list:
#     model_name = model.__class__.__name__
#     gridParams = dict()
#     if model_name =="XGBClassifier" :
#         gridParams["n_estimators"] = [20,50]
#         gridParams["max_depth"] = [10,20]
#         gridParams["min_child_weight"] = [1, 2,4]
#     elif model_name == "HistGradientBoostingClassifier" :
#         gridParams["max_iter"] = [20, 50]
#         gridParams["max_depth"] = [10, 50]
#         gridParams["min_samples_leaf"] = [1,2,4]
#     else :
#         gridParams["n_estimators"] = [20, 50]
#         gridParams["max_depth"] = [10,20]
#         gridParams["min_samples_split"] = [2,5,10]
#         gridParams["min_samples_leaf"] = [1,2,4]

#     grid_search_model = GridSearchCV(model, gridParams, scoring='f1', cv=5, n_jobs=-1)
#     grid_search_model.fit(X_train_scaled, y_train)
#     model = grid_search_model.best_estimator_
#     train_pred = model.predict(X_train_scaled)
#     val_pred = model.predict(X_val_scaled)
    
#     train_acc = accuracy_score(y_train, train_pred)
#     val_acc = accuracy_score(y_val, val_pred)
    
#     pre = precision_score(y_val, val_pred)
#     rec = recall_score(y_val, val_pred)
#     f1 = f1_score(y_val, val_pred)
    
#     pred = model.predict(X_test_scaled)
#     cm = confusion_matrix(y_test, pred)
#     TN = cm[0, 0]  # True Negative
#     FP = cm[0, 1]  # False Positive
#     FN = cm[1, 0]  # False Negative
#     TP = cm[1, 1]  # True Positive
    
#     df_temp = pd.DataFrame([[model_name,  train_acc, val_acc, pre, rec, f1, train_acc-val_acc, TN, FP, FN, TP, str(grid_search_model.best_params_)]],
#                              columns=["모델명", "훈련_정확도", "검증_정확도", "정밀도", "재현율", "f1-score", "훈련-검증", "TN", "FP", "FN", "TP", "파라미터"])

#     grid_df = pd.concat([grid_df, df_temp], ignore_index=True)
# grid_df

# %%
from scipy.stats import spearmanr, pearsonr
y = cn7["PassOrFail"]
X = cn7.drop(columns=["PassOrFail"])
for col_name in X.columns:
    print(col_name)
    print("피어슨")
    print(pearsonr(X[col_name], y))
    print("스피어만")
    print(spearmanr(X[col_name], y))
    print("==================================================================")
# Out:
# Injection_Time
# 피어슨
# PearsonRResult(statistic=0.3973768786237092, pvalue=3.657470066414128e-126)
# 스피어만
# SignificanceResult(statistic=0.23063949894561378, pvalue=2.2134072967540589e-41)
# ==================================================================
# Filling_Time
# 피어슨
# PearsonRResult(statistic=0.3974964042491591, pvalue=3.0315124502757e-126)
# 스피어만
# SignificanceResult(statistic=0.22828458171641663, pvalue=1.4872947872659528e-40)
# ==================================================================
# Plasticizing_Time
# 피어슨
# PearsonRResult(statistic=-0.39523293123853376, pvalue=1.0465068500475921e-124)
# 스피어만
# SignificanceResult(statistic=-0.29345739917002256, pvalue=5.1449101599946426e-67)
# ==================================================================
# Cycle_Time
# 피어슨
# PearsonRResult(statistic=0.38008336203235726, pvalue=1.0206904959324136e-114)
# 스피어만
# SignificanceResult(statistic=0.08193791055724713, pvalue=2.2425637786800358e-06)
# ==================================================================
# Clamp_Close_Time
# 피어슨
# PearsonRResult(statistic=0.5019963897372182, pvalue=9.779398114809177e-212)
# 스피어만
# SignificanceResult(statistic=0.656109848354027, pvalue=0.0)
# ==================================================================
# Cushion_Position
# 피어슨
# PearsonRResult(statistic=0.01593505398059416, pvalue=0.35839137600267884)
# 스피어만
# SignificanceResult(statistic=-0.37476611759875933, pvalue=2.4621939001094724e-111)
# ==================================================================
# Plasticizing_Position
# 피어슨
# PearsonRResult(statistic=0.545049281064125, pvalue=1.3076108749019217e-256)
# 스피어만
# SignificanceResult(statistic=0.6236979782364113, pvalue=0.0)
# ==================================================================
# Clamp_Open_Position
# 피어슨
# PearsonRResult(statistic=nan, pvalue=nan)
# 스피어만
# SignificanceResult(statistic=nan, pvalue=nan)
# ==================================================================
# Max_Injection_Speed
# 피어슨
# PearsonRResult(statistic=-0.37938070173947175, pvalue=2.8807657735098733e-114)
# 스피어만
# SignificanceResult(statistic=-0.27338878345971546, pvalue=4.633006029684261e-58)
# ==================================================================
# Max_Screw_RPM
# 피어슨
# PearsonRResult(statistic=0.13996220478841553, pvalue=5.218651591600315e-16)
# 스피어만
# SignificanceResult(statistic=0.1351405772533898, pvalue=5.100808790308658e-15)
# ==================================================================
# Average_Screw_RPM
# 피어슨
# PearsonRResult(statistic=-0.042031259422600636, pvalue=0.015374477516809449)
# 스피어만
# SignificanceResult(statistic=-0.06477432193601154, pvalue=0.00018620814363507282)
# ==================================================================
# Max_Injection_Pressure
# 피어슨
# PearsonRResult(statistic=0.38266352944616844, pvalue=2.2114890060494404e-116)
# 스피어만
# SignificanceResult(statistic=0.0593327413298934, pvalue=0.0006204651573072921)
# ==================================================================
# Max_Switch_Over_Pressure
# 피어슨
# PearsonRResult(statistic=0.4638276960039128, pvalue=5.342796209835388e-177)
# 스피어만
# SignificanceResult(statistic=0.4149573340974333, pvalue=1.6061145166904878e-138)
# ==================================================================
# Max_Back_Pressure
# 피어슨
# PearsonRResult(statistic=0.31144887273240746, pvalue=1.105723078690819e-75)
# 스피어만
# SignificanceResult(statistic=-0.07184492537598204, pvalue=3.38396173634992e-05)
# ==================================================================
# Average_Back_Pressure
# 피어슨
# PearsonRResult(statistic=0.30368229711822725, pvalue=7.260569075921935e-72)
# 스피어만
# SignificanceResult(statistic=-0.03352986807494265, pvalue=0.05324209449091723)
# ==================================================================
# Barrel_Temperature_1
# 피어슨
# PearsonRResult(statistic=-0.16948769253425272, pvalue=7.62728040980313e-23)
# 스피어만
# SignificanceResult(statistic=-0.166352770306639, pvalue=4.6970705793188115e-22)
# ==================================================================
# Barrel_Temperature_2
# 피어슨
# PearsonRResult(statistic=-0.13048376735960993, pvalue=4.272807843402369e-14)
# 스피어만
# SignificanceResult(statistic=-0.13677691376800877, pvalue=2.3744088697584087e-15)
# ==================================================================
# Barrel_Temperature_3
# 피어슨
# PearsonRResult(statistic=0.2733508014246887, pvalue=4.809640869112652e-58)
# 스피어만
# SignificanceResult(statistic=0.2931954244381584, pvalue=6.80871062508872e-67)
# ==================================================================
# Barrel_Temperature_4
# 피어슨
# PearsonRResult(statistic=0.12164327308251194, pvalue=1.9678197844517044e-12)
# 스피어만
# SignificanceResult(statistic=0.11885971635478781, pvalue=6.218184820424975e-12)
# ==================================================================
# Barrel_Temperature_5
# 피어슨
# PearsonRResult(statistic=0.16275190061755468, pvalue=3.628991224523521e-21)
# 스피어만
# SignificanceResult(statistic=0.18867068547260082, pvalue=5.1971746102431585e-28)
# ==================================================================
# Barrel_Temperature_6
# 피어슨
# PearsonRResult(statistic=-0.11491417882531259, pvalue=3.0361119923140264e-11)
# 스피어만
# SignificanceResult(statistic=-0.09693853828892296, pvalue=2.1435357639405208e-08)
# ==================================================================
# Hopper_Temperature
# 피어슨
# PearsonRResult(statistic=-0.3775238582387057, pvalue=4.4152639827975035e-113)
# 스피어만
# SignificanceResult(statistic=-0.3415215236846064, pvalue=1.3933635852571593e-91)
# ==================================================================
# Mold_Temperature_3
# 피어슨
# PearsonRResult(statistic=0.11092766185051661, pvalue=1.428401548428876e-10)
# 스피어만
# SignificanceResult(statistic=0.12019422797266995, pvalue=3.593647411254365e-12)
# ==================================================================
# Mold_Temperature_4
# 피어슨
# PearsonRResult(statistic=0.21814302533215768, pvalue=4.258014693568951e-37)
# 스피어만
# SignificanceResult(statistic=0.13321732690568472, pvalue=1.2382466325900893e-14)
# ==================================================================
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7852\2969300833.py:7: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   print(pearsonr(X[col_name], y))
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7852\2969300833.py:9: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   print(spearmanr(X[col_name], y))

# %%
cn7 =cn7.drop(columns=["Clamp_Open_Position"])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 20))
sns.heatmap(cn7.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
cn7.columns
# Out:
# Index(['Injection_Time', 'Filling_Time', 'Plasticizing_Time', 'Cycle_Time',
#        'Clamp_Close_Time', 'Cushion_Position', 'Plasticizing_Position',
#        'Max_Injection_Speed', 'Max_Screw_RPM', 'Average_Screw_RPM',
#        'Max_Injection_Pressure', 'Max_Switch_Over_Pressure',
#        'Max_Back_Pressure', 'Average_Back_Pressure', 'Barrel_Temperature_1',
#        'Barrel_Temperature_2', 'Barrel_Temperature_3', 'Barrel_Temperature_4',
#        'Barrel_Temperature_5', 'Barrel_Temperature_6', 'Hopper_Temperature',
#        'Mold_Temperature_3', 'Mold_Temperature_4', 'PassOrFail'],
#       dtype='object')

# %%
cn7[['Injection_Time', 'Filling_Time', 'Max_Injection_Speed', 'Max_Injection_Pressure', 'Max_Switch_Over_Pressure']]
# Out:
#       Injection_Time  Filling_Time  Max_Injection_Speed  \
# 0           9.580000      4.470000            55.400002
# 1           9.610000      4.490000            55.400002
# 2           9.520000      4.400000            56.400002
# 3           9.570000      4.450000            55.700001
# 4           9.640000      4.530000            54.799999
# ...              ...           ...                  ...
# 3319        9.448931      4.330000            60.889310
# 3320        9.450000      4.330000            60.712492
# 3321        9.571165      4.460000            55.534960
# 3322        9.646202      4.530685            54.241470
# 3323        9.570000      4.460000            55.500000
#
#       Max_Injection_Pressure  Max_Switch_Over_Pressure
# 0                 141.800003                136.600006
# 1                 142.199997                136.699997
# 2                 141.500000                135.699997
# 3                 141.699997                136.300003
# 4                 142.199997                137.199997
# ...                      ...                       ...
# 3319              141.399994                136.910686
# 3320              141.399994                136.806248
# 3321              141.711651                136.534961
# 3322              142.020672                137.041344
# 3323              141.699997                136.551046
#
# [3324 rows x 5 columns]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# 예시 데이터 생성 (PCA 대상 변수들)
data_pca = cn7[['Injection_Time', 'Filling_Time', 'Max_Injection_Speed', 'Max_Injection_Pressure', 'Max_Switch_Over_Pressure']].copy()

# 다른 변수들 (예시)
data_other = cn7.drop(columns=['Injection_Time', 'Filling_Time', 'Max_Injection_Speed', 'Max_Injection_Pressure', 'Max_Switch_Over_Pressure'])

# DataFrame 생성
df_pca = pd.DataFrame(data_pca)
df_other = pd.DataFrame(data_other)

# PCA 대상 변수들만 스케일링
scaler_pca = StandardScaler()
scaled_data_pca = scaler_pca.fit_transform(df_pca)

# PCA 적용 (1개의 주성분으로 축소)
pca = PCA(n_components=1)
principal_component = pca.fit_transform(scaled_data_pca)

# PCA 결과를 원래 데이터셋에 추가
cn7 = pd.concat([df_other, pd.DataFrame(principal_component, columns=["PCA_1"])], axis=1)

# 전체 데이터셋에 대해 다시 스케일링
cn7
# Out:
#       Plasticizing_Time  Cycle_Time  Clamp_Close_Time  Cushion_Position  \
# 0             16.889999   59.520000          7.130000        653.409973
# 1             16.860001   59.580002          7.120000        653.450012
# 2             17.100000   59.480000          7.120000        653.409973
# 3             16.930000   59.520000          7.120000        653.409973
# 4             16.750000   59.580002          7.120000        653.450012
# ...                 ...         ...               ...               ...
# 3319          16.928931   59.422136          7.130000        653.400024
# 3320          16.958125   59.570008          7.130000        653.400024
# 3321          16.906992   59.520000          7.130000        653.409973
# 3322          16.658293   59.211058          7.124483        653.432062
# 3323          16.910209   59.520000          7.130000        653.409973
#
#       Plasticizing_Position  Max_Screw_RPM  Average_Screw_RPM  \
# 0                 68.839996      30.600000         292.500000
# 1                 68.589996      30.600000         292.500000
# 2                 68.480003      31.000000         292.600006
# 3                 68.839996      30.700001         292.500000
# 4                 68.610001      30.900000         292.399994
# ...                     ...            ...                ...
# 3319              68.842135      30.878618         292.500000
# 3320              68.839996      30.806245         292.500000
# 3321              68.848833      30.546614         292.500000
# 3322              68.702076      30.544832         292.389657
# 3323              68.844893      30.602087         292.448954
#
#       Max_Back_Pressure  Average_Back_Pressure  Barrel_Temperature_1  \
# 0             37.599998              59.400002            276.100006
# 1             37.799999              59.500000            276.600006
# 2             38.099998              59.400002            276.500000
# 3             37.000000              59.000000            276.100006
# 4             38.599998              60.000000            276.299988
# ...                 ...                    ...                   ...
# 3319          36.321381              58.710692            276.625174
# 3320          37.050032              59.075016            275.387430
# 3321          37.465040              59.276692            276.530084
# 3322          38.151679              59.841346            276.486173
# 3323          37.346871              59.248957            276.242697
#
#       Barrel_Temperature_2  Barrel_Temperature_3  Barrel_Temperature_4  \
# 0               275.200012            275.100006            271.399994
# 1               275.899994            275.200012            269.299988
# 2               274.899994            275.100006            271.100006
# 3               275.600006            275.500000            270.100006
# 4               275.000000            275.299988            271.100006
# ...                    ...                   ...                   ...
# 3319            274.932069            274.889302            270.474832
# 3320            275.275005            275.087514            269.837463
# 3321            275.141745            275.169928            271.190232
# 3322            275.144841            275.431018            271.124153
# 3323            275.046873            275.355222            271.195824
#
#       Barrel_Temperature_5  Barrel_Temperature_6  Hopper_Temperature  \
# 0               255.199997            230.199997           67.800003
# 1               255.199997            229.800003           66.699997
# 2               254.899994            230.199997           68.800003
# 3               255.199997            229.699997           67.000000
# 4               254.800003            229.600006           65.500000
# ...                    ...                   ...                 ...
# 3319            254.878612            229.800003           67.000000
# 3320            254.993754            230.081269           67.937542
# 3321            254.676690            230.123313           67.806773
# 3322            255.310331            229.758651           65.979454
# 3323            255.057298            230.202091           67.491654
#
#       Mold_Temperature_3  Mold_Temperature_4  PassOrFail     PCA_1
# 0              25.000000           27.500000           1 -0.924311
# 1              22.600000           23.900000           0 -0.759864
# 2              23.700001           24.799999           0 -1.318978
# 3              25.000000           27.600000           0 -1.046050
# 4              20.299999           21.700001           0 -0.588834
# ...                  ...                 ...         ...       ...
# 3319           25.100000           27.689310           1 -1.628900
# 3320           25.006246           27.700001           1 -1.629419
# 3321           25.100000           27.700001           1 -0.983741
# 3322           22.572604           24.410586           1 -0.615826
# 3323           25.100000           27.700001           1 -0.982151
#
# [3324 rows x 20 columns]

# %%
from scipy.stats import spearmanr, pearsonr
y = cn7["PassOrFail"]
X = cn7.drop(columns=["PassOrFail"])
for col_name in X.columns:
    print(col_name)
    print("피어슨")
    print(pearsonr(X[col_name], y))
    print("스피어만")
    print(spearmanr(X[col_name], y))
    print("==================================================================")
# Out:
# Plasticizing_Time
# 피어슨
# PearsonRResult(statistic=-0.39523293123853376, pvalue=1.0465068500475921e-124)
# 스피어만
# SignificanceResult(statistic=-0.29345739917002256, pvalue=5.1449101599946426e-67)
# ==================================================================
# Cycle_Time
# 피어슨
# PearsonRResult(statistic=0.38008336203235726, pvalue=1.0206904959324136e-114)
# 스피어만
# SignificanceResult(statistic=0.08193791055724713, pvalue=2.2425637786800358e-06)
# ==================================================================
# Clamp_Close_Time
# 피어슨
# PearsonRResult(statistic=0.5019963897372182, pvalue=9.779398114809177e-212)
# 스피어만
# SignificanceResult(statistic=0.656109848354027, pvalue=0.0)
# ==================================================================
# Cushion_Position
# 피어슨
# PearsonRResult(statistic=0.01593505398059416, pvalue=0.35839137600267884)
# 스피어만
# SignificanceResult(statistic=-0.37476611759875933, pvalue=2.4621939001094724e-111)
# ==================================================================
# Plasticizing_Position
# 피어슨
# PearsonRResult(statistic=0.545049281064125, pvalue=1.3076108749019217e-256)
# 스피어만
# SignificanceResult(statistic=0.6236979782364113, pvalue=0.0)
# ==================================================================
# Max_Screw_RPM
# 피어슨
# PearsonRResult(statistic=0.13996220478841553, pvalue=5.218651591600315e-16)
# 스피어만
# SignificanceResult(statistic=0.1351405772533898, pvalue=5.100808790308658e-15)
# ==================================================================
# Average_Screw_RPM
# 피어슨
# PearsonRResult(statistic=-0.042031259422600636, pvalue=0.015374477516809449)
# 스피어만
# SignificanceResult(statistic=-0.06477432193601154, pvalue=0.00018620814363507282)
# ==================================================================
# Max_Back_Pressure
# 피어슨
# PearsonRResult(statistic=0.31144887273240746, pvalue=1.105723078690819e-75)
# 스피어만
# SignificanceResult(statistic=-0.07184492537598204, pvalue=3.38396173634992e-05)
# ==================================================================
# Average_Back_Pressure
# 피어슨
# PearsonRResult(statistic=0.30368229711822725, pvalue=7.260569075921935e-72)
# 스피어만
# SignificanceResult(statistic=-0.03352986807494265, pvalue=0.05324209449091723)
# ==================================================================
# Barrel_Temperature_1
# 피어슨
# PearsonRResult(statistic=-0.16948769253425272, pvalue=7.62728040980313e-23)
# 스피어만
# SignificanceResult(statistic=-0.166352770306639, pvalue=4.6970705793188115e-22)
# ==================================================================
# Barrel_Temperature_2
# 피어슨
# PearsonRResult(statistic=-0.13048376735960993, pvalue=4.272807843402369e-14)
# 스피어만
# SignificanceResult(statistic=-0.13677691376800877, pvalue=2.3744088697584087e-15)
# ==================================================================
# Barrel_Temperature_3
# 피어슨
# PearsonRResult(statistic=0.2733508014246887, pvalue=4.809640869112652e-58)
# 스피어만
# SignificanceResult(statistic=0.2931954244381584, pvalue=6.80871062508872e-67)
# ==================================================================
# Barrel_Temperature_4
# 피어슨
# PearsonRResult(statistic=0.12164327308251194, pvalue=1.9678197844517044e-12)
# 스피어만
# SignificanceResult(statistic=0.11885971635478781, pvalue=6.218184820424975e-12)
# ==================================================================
# Barrel_Temperature_5
# 피어슨
# PearsonRResult(statistic=0.16275190061755468, pvalue=3.628991224523521e-21)
# 스피어만
# SignificanceResult(statistic=0.18867068547260082, pvalue=5.1971746102431585e-28)
# ==================================================================
# Barrel_Temperature_6
# 피어슨
# PearsonRResult(statistic=-0.11491417882531259, pvalue=3.0361119923140264e-11)
# 스피어만
# SignificanceResult(statistic=-0.09693853828892296, pvalue=2.1435357639405208e-08)
# ==================================================================
# Hopper_Temperature
# 피어슨
# PearsonRResult(statistic=-0.3775238582387057, pvalue=4.4152639827975035e-113)
# 스피어만
# SignificanceResult(statistic=-0.3415215236846064, pvalue=1.3933635852571593e-91)
# ==================================================================
# Mold_Temperature_3
# 피어슨
# PearsonRResult(statistic=0.11092766185051661, pvalue=1.428401548428876e-10)
# 스피어만
# SignificanceResult(statistic=0.12019422797266995, pvalue=3.593647411254365e-12)
# ==================================================================
# Mold_Temperature_4
# 피어슨
# PearsonRResult(statistic=0.21814302533215768, pvalue=4.258014693568951e-37)
# 스피어만
# SignificanceResult(statistic=0.13321732690568472, pvalue=1.2382466325900893e-14)
# ==================================================================
# PCA_1
# 피어슨
# PearsonRResult(statistic=0.409750536128291, pvalue=8.779796853212811e-135)
# 스피어만
# SignificanceResult(statistic=0.19974906803761777, pvalue=2.9209408039893185e-31)
# ==================================================================

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# VIF 계산을 위한 함수 정의
def calculate_vif(data):
    vif = pd.DataFrame()
    vif["Variable"] = data.columns
    vif["VIF"] = [calculate_single_vif(data, i) for i in range(data.shape[1])]
    return vif

# 각 변수에 대해 VIF 계산
def calculate_single_vif(data, i):
    # 독립변수(다른 변수들)와 회귀 모델을 적합
    x = data.drop(data.columns[i], axis=1)  # 해당 변수 이외의 변수들
    y = data.iloc[:, i]  # 해당 변수
    model = LinearRegression()
    model.fit(x, y)
    # R^2 값 계산
    r2 = model.score(x, y)
    # VIF 계산: 1 / (1 - R^2)
    return 1 / (1 - r2)

# 'PassOrFail'을 제외한 수치형 데이터 선택
numeric_columns = cn7.select_dtypes(include=['float64', 'int32']).columns
numeric_columns = [col for col in numeric_columns if col != 'PassOrFail']  # 'PassOrFail' 제외

# VIF 데이터 선택
vif_data = cn7[numeric_columns]

# VIF 계산
vif_result = calculate_vif(vif_data)

# VIF 결과 출력
vif_result.sort_values(by="VIF", ascending=False)
# Out:
#                  Variable          VIF
# 17     Mold_Temperature_4  1188.307484
# 7       Max_Back_Pressure  1012.620781
# 8   Average_Back_Pressure   844.389869
# 16     Mold_Temperature_3   700.138581
# 4   Plasticizing_Position    92.915500
# 18                  PCA_1    62.213755
# 3        Cushion_Position    53.842047
# 1              Cycle_Time    36.504590
# 2        Clamp_Close_Time    18.486455
# 0       Plasticizing_Time    17.304635
# 15     Hopper_Temperature    14.363728
# 6       Average_Screw_RPM     3.585573
# 5           Max_Screw_RPM     2.710765
# 12   Barrel_Temperature_4     1.861066
# 14   Barrel_Temperature_6     1.781234
# 11   Barrel_Temperature_3     1.542095
# 9    Barrel_Temperature_1     1.502891
# 13   Barrel_Temperature_5     1.439520
# 10   Barrel_Temperature_2     1.200369

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 20))
sns.heatmap(cn7.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
cn7.columns
# Out:
# Index(['Plasticizing_Time', 'Cycle_Time', 'Clamp_Close_Time',
#        'Cushion_Position', 'Plasticizing_Position', 'Max_Screw_RPM',
#        'Average_Screw_RPM', 'Max_Back_Pressure', 'Average_Back_Pressure',
#        'Barrel_Temperature_1', 'Barrel_Temperature_2', 'Barrel_Temperature_3',
#        'Barrel_Temperature_4', 'Barrel_Temperature_5', 'Barrel_Temperature_6',
#        'Hopper_Temperature', 'Mold_Temperature_3', 'Mold_Temperature_4',
#        'PassOrFail', 'PCA_1'],
#       dtype='object')

# %%
data_pca = cn7[["Max_Back_Pressure", "Average_Back_Pressure"]].copy()

# 다른 변수들 (예시)
data_other = cn7.drop(columns=["Max_Back_Pressure", "Average_Back_Pressure"])

# DataFrame 생성
df_pca = pd.DataFrame(data_pca)
df_other = pd.DataFrame(data_other)

# PCA 대상 변수들만 스케일링
scaler_pca = StandardScaler()
scaled_data_pca = scaler_pca.fit_transform(df_pca)

# PCA 적용 (1개의 주성분으로 축소)
pca = PCA(n_components=1)
principal_component = pca.fit_transform(scaled_data_pca)

# PCA 결과를 원래 데이터셋에 추가
cn7 = pd.concat([df_other, pd.DataFrame(principal_component, columns=["Back_Pressure"])], axis=1)

data_pca = cn7[["Mold_Temperature_3", "Mold_Temperature_4"]].copy()

# 다른 변수들 (예시)
data_other = cn7.drop(columns=["Mold_Temperature_3", "Mold_Temperature_4"])

# DataFrame 생성
df_pca = pd.DataFrame(data_pca)
df_other = pd.DataFrame(data_other)

# PCA 대상 변수들만 스케일링
scaler_pca = StandardScaler()
scaled_data_pca = scaler_pca.fit_transform(df_pca)

# PCA 적용 (1개의 주성분으로 축소)
pca = PCA(n_components=1)
principal_component = pca.fit_transform(scaled_data_pca)

# PCA 결과를 원래 데이터셋에 추가
cn7 = pd.concat([df_other, pd.DataFrame(principal_component, columns=["Mold_Temperature"])], axis=1)
cn7
# Out:
#       Plasticizing_Time  Cycle_Time  Clamp_Close_Time  Cushion_Position  \
# 0             16.889999   59.520000          7.130000        653.409973
# 1             16.860001   59.580002          7.120000        653.450012
# 2             17.100000   59.480000          7.120000        653.409973
# 3             16.930000   59.520000          7.120000        653.409973
# 4             16.750000   59.580002          7.120000        653.450012
# ...                 ...         ...               ...               ...
# 3319          16.928931   59.422136          7.130000        653.400024
# 3320          16.958125   59.570008          7.130000        653.400024
# 3321          16.906992   59.520000          7.130000        653.409973
# 3322          16.658293   59.211058          7.124483        653.432062
# 3323          16.910209   59.520000          7.130000        653.409973
#
#       Plasticizing_Position  Max_Screw_RPM  Average_Screw_RPM  \
# 0                 68.839996      30.600000         292.500000
# 1                 68.589996      30.600000         292.500000
# 2                 68.480003      31.000000         292.600006
# 3                 68.839996      30.700001         292.500000
# 4                 68.610001      30.900000         292.399994
# ...                     ...            ...                ...
# 3319              68.842135      30.878618         292.500000
# 3320              68.839996      30.806245         292.500000
# 3321              68.848833      30.546614         292.500000
# 3322              68.702076      30.544832         292.389657
# 3323              68.844893      30.602087         292.448954
#
#       Barrel_Temperature_1  Barrel_Temperature_2  Barrel_Temperature_3  \
# 0               276.100006            275.200012            275.100006
# 1               276.600006            275.899994            275.200012
# 2               276.500000            274.899994            275.100006
# 3               276.100006            275.600006            275.500000
# 4               276.299988            275.000000            275.299988
# ...                    ...                   ...                   ...
# 3319            276.625174            274.932069            274.889302
# 3320            275.387430            275.275005            275.087514
# 3321            276.530084            275.141745            275.169928
# 3322            276.486173            275.144841            275.431018
# 3323            276.242697            275.046873            275.355222
#
#       Barrel_Temperature_4  Barrel_Temperature_5  Barrel_Temperature_6  \
# 0               271.399994            255.199997            230.199997
# 1               269.299988            255.199997            229.800003
# 2               271.100006            254.899994            230.199997
# 3               270.100006            255.199997            229.699997
# 4               271.100006            254.800003            229.600006
# ...                    ...                   ...                   ...
# 3319            270.474832            254.878612            229.800003
# 3320            269.837463            254.993754            230.081269
# 3321            271.190232            254.676690            230.123313
# 3322            271.124153            255.310331            229.758651
# 3323            271.195824            255.057298            230.202091
#
#       Hopper_Temperature  PassOrFail     PCA_1  Back_Pressure  \
# 0              67.800003           1 -0.924311      -0.488360
# 1              66.699997           0 -0.759864      -0.454962
# 2              68.800003           0 -1.318978      -0.437695
# 3              67.000000           0 -1.046050      -0.601686
# 4              65.500000           0 -0.588834      -0.308238
# ...                  ...         ...       ...            ...
# 3319           67.000000           1 -1.628900      -0.708442
# 3320           67.937542           1 -1.629419      -0.586765
# 3321           67.806773           1 -0.983741      -0.518228
# 3322           65.979454           1 -0.615826      -0.374501
# 3323           67.491654           1 -0.982151      -0.533844
#
#       Mold_Temperature
# 0             1.691860
# 1            -0.300077
# 2             0.390755
# 3             1.721478
# 4            -1.838784
# ...                ...
# 3319          1.786500
# 3320          1.753506
# 3321          1.789667
# 3322         -0.159415
# 3323          1.789667
#
# [3324 rows x 18 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 20))
sns.heatmap(cn7.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# VIF 계산을 위한 함수 정의
def calculate_vif(data):
    vif = pd.DataFrame()
    vif["Variable"] = data.columns
    vif["VIF"] = [calculate_single_vif(data, i) for i in range(data.shape[1])]
    return vif

# 각 변수에 대해 VIF 계산
def calculate_single_vif(data, i):
    # 독립변수(다른 변수들)와 회귀 모델을 적합
    x = data.drop(data.columns[i], axis=1)  # 해당 변수 이외의 변수들
    y = data.iloc[:, i]  # 해당 변수
    model = LinearRegression()
    model.fit(x, y)
    # R^2 값 계산
    r2 = model.score(x, y)
    # VIF 계산: 1 / (1 - R^2)
    return 1 / (1 - r2)

# 'PassOrFail'을 제외한 수치형 데이터 선택
numeric_columns = cn7.select_dtypes(include=['float64', 'int32']).columns
numeric_columns = [col for col in numeric_columns if col != 'PassOrFail']  # 'PassOrFail' 제외

# VIF 데이터 선택
vif_data = cn7[numeric_columns]

# VIF 계산
vif_result = calculate_vif(vif_data)

# VIF 결과 출력
vif_result.sort_values(by="VIF", ascending=False)
# Out:
#                  Variable        VIF
# 14                  PCA_1  37.684257
# 1              Cycle_Time  30.837979
# 16       Mold_Temperature  28.943599
# 3        Cushion_Position  27.501232
# 4   Plasticizing_Position  19.413098
# 13     Hopper_Temperature  13.418963
# 0       Plasticizing_Time  12.705611
# 2        Clamp_Close_Time  12.199113
# 15          Back_Pressure   7.923519
# 6       Average_Screw_RPM   2.792930
# 5           Max_Screw_RPM   2.623241
# 10   Barrel_Temperature_4   1.823048
# 12   Barrel_Temperature_6   1.742689
# 9    Barrel_Temperature_3   1.542052
# 7    Barrel_Temperature_1   1.499650
# 11   Barrel_Temperature_5   1.437541
# 8    Barrel_Temperature_2   1.190646

# %%
data_pca = cn7[['Cycle_Time', 'Clamp_Close_Time']].copy()

# 다른 변수들 (예시)
data_other = cn7.drop(columns=['Cycle_Time', 'Clamp_Close_Time'])

# DataFrame 생성
df_pca = pd.DataFrame(data_pca)
df_other = pd.DataFrame(data_other)

# PCA 대상 변수들만 스케일링
scaler_pca = StandardScaler()
scaled_data_pca = scaler_pca.fit_transform(df_pca)

# PCA 적용 (1개의 주성분으로 축소)
pca = PCA(n_components=1)
principal_component = pca.fit_transform(scaled_data_pca)

# PCA 결과를 원래 데이터셋에 추가
cn7 = pd.concat([df_other, pd.DataFrame(principal_component, columns=["Time"])], axis=1)

data_pca = cn7[['Plasticizing_Time',  'Hopper_Temperature']].copy()

# 다른 변수들 (예시)
data_other = cn7.drop(columns=['Plasticizing_Time',  'Hopper_Temperature'])

# DataFrame 생성
df_pca = pd.DataFrame(data_pca)
df_other = pd.DataFrame(data_other)

# PCA 대상 변수들만 스케일링
scaler_pca = StandardScaler()
scaled_data_pca = scaler_pca.fit_transform(df_pca)

# PCA 적용 (1개의 주성분으로 축소)
pca = PCA(n_components=1)
principal_component = pca.fit_transform(scaled_data_pca)

# PCA 결과를 원래 데이터셋에 추가
cn7 = pd.concat([df_other, pd.DataFrame(principal_component, columns=["PCA_2"])], axis=1)
cn7
# Out:
#       Cushion_Position  Plasticizing_Position  Max_Screw_RPM  \
# 0           653.409973              68.839996      30.600000
# 1           653.450012              68.589996      30.600000
# 2           653.409973              68.480003      31.000000
# 3           653.409973              68.839996      30.700001
# 4           653.450012              68.610001      30.900000
# ...                ...                    ...            ...
# 3319        653.400024              68.842135      30.878618
# 3320        653.400024              68.839996      30.806245
# 3321        653.409973              68.848833      30.546614
# 3322        653.432062              68.702076      30.544832
# 3323        653.409973              68.844893      30.602087
#
#       Average_Screw_RPM  Barrel_Temperature_1  Barrel_Temperature_2  \
# 0            292.500000            276.100006            275.200012
# 1            292.500000            276.600006            275.899994
# 2            292.600006            276.500000            274.899994
# 3            292.500000            276.100006            275.600006
# 4            292.399994            276.299988            275.000000
# ...                 ...                   ...                   ...
# 3319         292.500000            276.625174            274.932069
# 3320         292.500000            275.387430            275.275005
# 3321         292.500000            276.530084            275.141745
# 3322         292.389657            276.486173            275.144841
# 3323         292.448954            276.242697            275.046873
#
#       Barrel_Temperature_3  Barrel_Temperature_4  Barrel_Temperature_5  \
# 0               275.100006            271.399994            255.199997
# 1               275.200012            269.299988            255.199997
# 2               275.100006            271.100006            254.899994
# 3               275.500000            270.100006            255.199997
# 4               275.299988            271.100006            254.800003
# ...                    ...                   ...                   ...
# 3319            274.889302            270.474832            254.878612
# 3320            275.087514            269.837463            254.993754
# 3321            275.169928            271.190232            254.676690
# 3322            275.431018            271.124153            255.310331
# 3323            275.355222            271.195824            255.057298
#
#       Barrel_Temperature_6  PassOrFail     PCA_1  Back_Pressure  \
# 0               230.199997           1 -0.924311      -0.488360
# 1               229.800003           0 -0.759864      -0.454962
# 2               230.199997           0 -1.318978      -0.437695
# 3               229.699997           0 -1.046050      -0.601686
# 4               229.600006           0 -0.588834      -0.308238
# ...                    ...         ...       ...            ...
# 3319            229.800003           1 -1.628900      -0.708442
# 3320            230.081269           1 -1.629419      -0.586765
# 3321            230.123313           1 -0.983741      -0.518228
# 3322            229.758651           1 -0.615826      -0.374501
# 3323            230.202091           1 -0.982151      -0.533844
#
#       Mold_Temperature      Time     PCA_2
# 0             1.691860 -0.256227  0.649734
# 1            -0.300077 -0.683961 -0.002891
# 2             0.390755 -0.775642  2.151619
# 3             1.721478 -0.738969  0.482479
# 4            -1.838784 -0.683961 -1.099077
# ...                ...       ...       ...
# 3319          1.786500 -0.345947  0.477163
# 3320          1.753506 -0.210381  1.051430
# 3321          1.789667 -0.256227  0.737324
# 3322         -0.159415 -0.805781 -1.335632
# 3323          1.789667 -0.256227  0.609092
#
# [3324 rows x 16 columns]

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd

# VIF 계산을 위한 함수 정의
def calculate_vif(data):
    vif = pd.DataFrame()
    vif["Variable"] = data.columns
    vif["VIF"] = [calculate_single_vif(data, i) for i in range(data.shape[1])]
    return vif

# 각 변수에 대해 VIF 계산
def calculate_single_vif(data, i):
    # 독립변수(다른 변수들)와 회귀 모델을 적합
    x = data.drop(data.columns[i], axis=1)  # 해당 변수 이외의 변수들
    y = data.iloc[:, i]  # 해당 변수
    model = LinearRegression()
    model.fit(x, y)
    # R^2 값 계산
    r2 = model.score(x, y)
    # VIF 계산: 1 / (1 - R^2)
    return 1 / (1 - r2)

# 'PassOrFail'을 제외한 수치형 데이터 선택
numeric_columns = cn7.select_dtypes(include=['float64', 'int32']).columns
numeric_columns = [col for col in numeric_columns if col != 'PassOrFail']  # 'PassOrFail' 제외

# VIF 데이터 선택
vif_data = cn7[numeric_columns]

# VIF 계산
vif_result = calculate_vif(vif_data)

# VIF 결과 출력
vif_result.sort_values(by="VIF", ascending=False)
# Out:
#                  Variable        VIF
# 10                  PCA_1  32.249712
# 12       Mold_Temperature  27.402822
# 0        Cushion_Position  23.900521
# 1   Plasticizing_Position  16.525563
# 14                  PCA_2  13.710277
# 13                   Time  12.127676
# 11          Back_Pressure   6.486052
# 3       Average_Screw_RPM   2.581216
# 2           Max_Screw_RPM   2.140041
# 7    Barrel_Temperature_4   1.656993
# 9    Barrel_Temperature_6   1.630058
# 6    Barrel_Temperature_3   1.480761
# 4    Barrel_Temperature_1   1.458230
# 8    Barrel_Temperature_5   1.424600
# 5    Barrel_Temperature_2   1.133853

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 20))
sns.heatmap(cn7.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
cn7.columns
# Out:
# Index(['Cushion_Position', 'Plasticizing_Position', 'Max_Screw_RPM',
#        'Average_Screw_RPM', 'Barrel_Temperature_1', 'Barrel_Temperature_2',
#        'Barrel_Temperature_3', 'Barrel_Temperature_4', 'Barrel_Temperature_5',
#        'Barrel_Temperature_6', 'PassOrFail', 'PCA_1', 'Back_Pressure',
#        'Mold_Temperature', 'Time', 'PCA_2'],
#       dtype='object')

# %%
data_pca = cn7[['Plasticizing_Position',  'Mold_Temperature', "PCA_1", "PCA_2", "Cushion_Position"]].copy()

# 다른 변수들 (예시)
data_other = cn7.drop(columns=['Plasticizing_Position',  'Mold_Temperature', "PCA_1", "PCA_2", "Cushion_Position"])

# DataFrame 생성
df_pca = pd.DataFrame(data_pca)
df_other = pd.DataFrame(data_other)

# PCA 대상 변수들만 스케일링
scaler_pca = StandardScaler()
scaled_data_pca = scaler_pca.fit_transform(df_pca)

# PCA 적용 (1개의 주성분으로 축소)
pca = PCA(n_components=1)
principal_component = pca.fit_transform(scaled_data_pca)

# PCA 결과를 원래 데이터셋에 추가
cn7 = pd.concat([df_other, pd.DataFrame(principal_component, columns=["PCA_1"])], axis=1)

data_pca = cn7[['Time', 'Back_Pressure']].copy()

# 다른 변수들 (예시)
data_other = cn7.drop(columns=['Time', 'Back_Pressure'])

# DataFrame 생성
df_pca = pd.DataFrame(data_pca)
df_other = pd.DataFrame(data_other)

# PCA 대상 변수들만 스케일링
scaler_pca = StandardScaler()
scaled_data_pca = scaler_pca.fit_transform(df_pca)

# PCA 적용 (1개의 주성분으로 축소)
pca = PCA(n_components=1)
principal_component = pca.fit_transform(scaled_data_pca)

# PCA 결과를 원래 데이터셋에 추가
cn7 = pd.concat([df_other, pd.DataFrame(principal_component, columns=["PCA_2"])], axis=1)

cn7
