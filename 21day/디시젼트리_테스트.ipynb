# %%
### 시각화를 위한 라이브러리
# - 파이썬 시각화에서 가장 기본적인 시각화 라이브러리
import matplotlib.pyplot as plt

### 한글처리
from matplotlib import font_manager, rc

### 운영체제 확인 라이브러리
import platform

### 시각화 시 마이너스(-, 음수) 기호 깨짐 방지
plt.rcParams["axes.unicode_minus"] = False

### OS별 한글처리
# - 윈도우 운영체게
if platform.system() == "Windows" :
    # path = "c:/Windows/Fonts/malgun.ttf"
    # font_name = font_manager.FontProperties(fname=path).get_name()
    # rc("font", family = font_name)
    
    ### 또는 아래처럼 한줄로도 가능 (아래 한글처리를 주로 사용합니다.)
    plt.rc("font", family = "Malgun Gothic")

# - Mac 운영체제
elif platform.system() == "Darwin" :
    rc("font", family = "AppleGothic")
    
else :
    print("넌 누구?")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

cn7 = pd.read_csv("./cn7_resampled.csv")


# 데이터 준비 (cn7 데이터프레임 사용)
X = cn7.drop('PassOrFail', axis=1)
y = cn7['PassOrFail']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 모델 학습
model = DecisionTreeClassifier(random_state= 42)
model.fit(X_train, y_train)

# 성능 확인
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 0.99

# %%
# 학습된 디시젼트리 모델 내부 구조 접근
tree = model.tree_

# 전체 노드 개수와 최대 깊이 출력
print("노드 개수:", tree.node_count)
print("최대 깊이:", tree.max_depth)

# 예시: 처음 10개 노드의 정보를 출력
for i in range(min(100, tree.node_count)):  
    print(f"\n노드 {i}:")
    print(" 왼쪽 자식 인덱스:", tree.children_left[i])
    print(" 오른쪽 자식 인덱스:", tree.children_right[i])
    print(" 사용된 특성 인덱스:", tree.feature[i])
    print(" 변수명:", X.columns[tree.feature[i]])
    print(" 임계값:", tree.threshold[i])
    print(" 노드 내 클래스별 샘플 수:", tree.value[i])
# Out:
# 노드 개수: 47
# 최대 깊이: 13
#
# 노드 0:
#  왼쪽 자식 인덱스: 1
#  오른쪽 자식 인덱스: 4
#  사용된 특성 인덱스: 4
#  변수명: Clamp_Close_Time
#  임계값: 7.120026111602783
#  노드 내 클래스별 샘플 수: [[0.48538263 0.51461737]]
#
# 노드 1:
#  왼쪽 자식 인덱스: 2
#  오른쪽 자식 인덱스: 3
#  사용된 특성 인덱스: 8
#  변수명: Max_Injection_Speed
#  임계값: 54.04999923706055
#  노드 내 클래스별 샘플 수: [[0.84295175 0.15704825]]
#
# 노드 2:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[0. 1.]]
#
# 노드 3:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[1. 0.]]
#
# 노드 4:
#  왼쪽 자식 인덱스: 5
#  오른쪽 자식 인덱스: 6
#  사용된 특성 인덱스: 6
#  변수명: Plasticizing_Position
#  임계값: 68.54500198364258
#  노드 내 클래스별 샘플 수: [[0.18754925 0.81245075]]
#
# 노드 5:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[1. 0.]]
#
# 노드 6:
#  왼쪽 자식 인덱스: 7
#  오른쪽 자식 인덱스: 8
#  사용된 특성 인덱스: 12
#  변수명: Max_Switch_Over_Pressure
#  임계값: 136.10195922851562
#  노드 내 클래스별 샘플 수: [[0.04003724 0.95996276]]
#
# 노드 7:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[1. 0.]]
#
# 노드 8:
#  왼쪽 자식 인덱스: 9
#  오른쪽 자식 인덱스: 42
#  사용된 특성 인덱스: 6
#  변수명: Plasticizing_Position
#  임계값: 68.85994720458984
#  노드 내 클래스별 샘플 수: [[0.03373946 0.96626054]]
#
# 노드 9:
#  왼쪽 자식 인덱스: 10
#  오른쪽 자식 인덱스: 41
#  사용된 특성 인덱스: 15
#  변수명: Barrel_Temperature_1
#  임계값: 277.14662170410156
#  노드 내 클래스별 샘플 수: [[0.02924528 0.97075472]]
#
# 노드 10:
#  왼쪽 자식 인덱스: 11
#  오른쪽 자식 인덱스: 16
#  사용된 특성 인덱스: 10
#  변수명: Average_Screw_RPM
#  임계값: 292.4003143310547
#  노드 내 클래스별 샘플 수: [[0.02741021 0.97258979]]
#
# 노드 11:
#  왼쪽 자식 인덱스: 12
#  오른쪽 자식 인덱스: 13
#  사용된 특성 인덱스: 6
#  변수명: Plasticizing_Position
#  임계값: 68.82715225219727
#  노드 내 클래스별 샘플 수: [[0.13274336 0.86725664]]
#
# 노드 12:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[0. 1.]]
#
# 노드 13:
#  왼쪽 자식 인덱스: 14
#  오른쪽 자식 인덱스: 15
#  사용된 특성 인덱스: 16
#  변수명: Barrel_Temperature_2
#  임계값: 274.9499969482422
#  노드 내 클래스별 샘플 수: [[0.9375 0.0625]]
#
# 노드 14:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[0. 1.]]
#
# 노드 15:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[1. 0.]]
#
# 노드 16:
#  왼쪽 자식 인덱스: 17
#  오른쪽 자식 인덱스: 24
#  사용된 특성 인덱스: 12
#  변수명: Max_Switch_Over_Pressure
#  임계값: 136.5001678466797
#  노드 내 클래스별 샘플 수: [[0.01481481 0.98518519]]
#
# 노드 17:
#  왼쪽 자식 인덱스: 18
#  오른쪽 자식 인덱스: 21
#  사용된 특성 인덱스: 9
#  변수명: Max_Screw_RPM
#  임계값: 30.79978084564209
#  노드 내 클래스별 샘플 수: [[0.06956522 0.93043478]]
#
# 노드 18:
#  왼쪽 자식 인덱스: 19
#  오른쪽 자식 인덱스: 20
#  사용된 특성 인덱스: 18
#  변수명: Barrel_Temperature_4
#  임계값: 271.3944396972656
#  노드 내 클래스별 샘플 수: [[0.00943396 0.99056604]]
#
# 노드 19:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[0. 1.]]
#
# 노드 20:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[0.5 0.5]]
#
# 노드 21:
#  왼쪽 자식 인덱스: 22
#  오른쪽 자식 인덱스: 23
#  사용된 특성 인덱스: 2
#  변수명: Plasticizing_Time
#  임계값: 16.94020366668701
#  노드 내 클래스별 샘플 수: [[0.77777778 0.22222222]]
#
# 노드 22:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[1. 0.]]
#
# 노드 23:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[0. 1.]]
#
# 노드 24:
#  왼쪽 자식 인덱스: 25
#  오른쪽 자식 인덱스: 26
#  사용된 특성 인덱스: 17
#  변수명: Barrel_Temperature_3
#  임계값: 274.5296173095703
#  노드 내 클래스별 샘플 수: [[0.00722892 0.99277108]]
#
# 노드 25:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[1. 0.]]
#
# 노드 26:
#  왼쪽 자식 인덱스: 27
#  오른쪽 자식 인덱스: 38
#  사용된 특성 인덱스: 17
#  변수명: Barrel_Temperature_3
#  임계값: 275.6953582763672
#  노드 내 클래스별 샘플 수: [[0.00603136 0.99396864]]
#
# 노드 27:
#  왼쪽 자식 인덱스: 28
#  오른쪽 자식 인덱스: 35
#  사용된 특성 인덱스: 9
#  변수명: Max_Screw_RPM
#  임계값: 30.997658729553223
#  노드 내 클래스별 샘플 수: [[0.00486027 0.99513973]]
#
# 노드 28:
#  왼쪽 자식 인덱스: 29
#  오른쪽 자식 인덱스: 30
#  사용된 특성 인덱스: 18
#  변수명: Barrel_Temperature_4
#  임계값: 271.39813232421875
#  노드 내 클래스별 샘플 수: [[0.00372671 0.99627329]]
#
# 노드 29:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[0. 1.]]
#
# 노드 30:
#  왼쪽 자식 인덱스: 31
#  오른쪽 자식 인덱스: 34
#  사용된 특성 인덱스: 17
#  변수명: Barrel_Temperature_3
#  임계값: 275.2707214355469
#  노드 내 클래스별 샘플 수: [[0.01775148 0.98224852]]
#
# 노드 31:
#  왼쪽 자식 인덱스: 32
#  오른쪽 자식 인덱스: 33
#  사용된 특성 인덱스: 20
#  변수명: Barrel_Temperature_6
#  임계값: 230.19890594482422
#  노드 내 클래스별 샘플 수: [[0.00598802 0.99401198]]
#
# 노드 32:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[0. 1.]]
#
# 노드 33:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[1. 0.]]
#
# 노드 34:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[1. 0.]]
#
# 노드 35:
#  왼쪽 자식 인덱스: 36
#  오른쪽 자식 인덱스: 37
#  사용된 특성 인덱스: 20
#  변수명: Barrel_Temperature_6
#  임계값: 229.8966827392578
#  노드 내 클래스별 샘플 수: [[0.05555556 0.94444444]]
#
# 노드 36:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[0. 1.]]
#
# 노드 37:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[1. 0.]]
#
# 노드 38:
#  왼쪽 자식 인덱스: 39
#  오른쪽 자식 인덱스: 40
#  사용된 특성 인덱스: 5
#  변수명: Cushion_Position
#  임계값: 653.4128112792969
#  노드 내 클래스별 샘플 수: [[0.16666667 0.83333333]]
#
# 노드 39:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[0.5 0.5]]
#
# 노드 40:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[0. 1.]]
#
# 노드 41:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[1. 0.]]
#
# 노드 42:
#  왼쪽 자식 인덱스: 43
#  오른쪽 자식 인덱스: 44
#  사용된 특성 인덱스: 2
#  변수명: Plasticizing_Time
#  임계값: 16.914999961853027
#  노드 내 클래스별 샘플 수: [[0.71428571 0.28571429]]
#
# 노드 43:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[1. 0.]]
#
# 노드 44:
#  왼쪽 자식 인덱스: 45
#  오른쪽 자식 인덱스: 46
#  사용된 특성 인덱스: 21
#  변수명: Hopper_Temperature
#  임계값: 66.79999923706055
#  노드 내 클래스별 샘플 수: [[0.33333333 0.66666667]]
#
# 노드 45:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[1. 0.]]
#
# 노드 46:
#  왼쪽 자식 인덱스: -1
#  오른쪽 자식 인덱스: -1
#  사용된 특성 인덱스: -2
#  변수명: Mold_Temperature_3
#  임계값: -2.0
#  노드 내 클래스별 샘플 수: [[0. 1.]]

# %%
cn7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3324 entries, 0 to 3323
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Injection_Time            3324 non-null   float64
#  1   Filling_Time              3324 non-null   float64
#  2   Plasticizing_Time         3324 non-null   float64
#  3   Cycle_Time                3324 non-null   float64
#  4   Clamp_Close_Time          3324 non-null   float64
#  5   Cushion_Position          3324 non-null   float64
#  6   Plasticizing_Position     3324 non-null   float64
#  7   Clamp_Open_Position       3324 non-null   float64
#  8   Max_Injection_Speed       3324 non-null   float64
#  9   Max_Screw_RPM             3324 non-null   float64
#  10  Average_Screw_RPM         3324 non-null   float64
#  11  Max_Injection_Pressure    3324 non-null   float64
#  12  Max_Switch_Over_Pressure  3324 non-null   float64
#  13  Max_Back_Pressure         3324 non-null   float64
#  14  Average_Back_Pressure     3324 non-null   float64
#  15  Barrel_Temperature_1      3324 non-null   float64
#  16  Barrel_Temperature_2      3324 non-null   float64
#  17  Barrel_Temperature_3      3324 non-null   float64
#  18  Barrel_Temperature_4      3324 non-null   float64
#  19  Barrel_Temperature_5      3324 non-null   float64
#  20  Barrel_Temperature_6      3324 non-null   float64
#  21  Hopper_Temperature        3324 non-null   float64
#  22  Mold_Temperature_3        3324 non-null   float64
#  23  Mold_Temperature_4        3324 non-null   float64
#  24  PassOrFail                3324 non-null   int64
# dtypes: float64(24), int64(1)
# memory usage: 649.3 KB

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import dtreeviz  # dtreeviz 모듈 설치 필수

# [예시] cn7 DataFrame이 이미 존재한다고 가정
# cn7.info()로 확인한 결과, 'PassOrFail' 컬럼이 타깃임
X = cn7.drop(columns=['PassOrFail'])
y = cn7['PassOrFail']

# 디시젼 트리 모델 학습 (최대 깊이는 4로 설정)
clf = DecisionTreeClassifier(max_depth=4)
clf.fit(X, y)

# dtreeviz를 이용한 트리 시각화  
viz_model = dtreeviz.model(clf,
                           X_train=X, y_train=y,
                           feature_names=X.columns.tolist(),  # 피처 이름 리스트
                           target_name='PassOrFail',            # 타깃 변수 이름
                           class_names=['Fail', 'Pass'])        # 클래스 이름 (타깃 값 0, 1에 해당)

# SVG 객체로 렌더링 후, 화면에 표시하거나 파일로 저장
v = viz_model.view()     # SVG 객체 생성
v.show()                 # 결과를 팝업 창 등에서 확인 (인터랙티브 환경)
v.save("/tmp/cn7_decision_tree.svg")  # 선택 사항: SVG 파일로 저장
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 15
#      12 clf.fit(X, y)
#      14 # dtreeviz를 이용한 트리 시각화
# ---> 15 viz_model = dtreeviz.model(clf,
#      16                            X_train=X, y_train=y,
#      17                            feature_names=X.columns.tolist(),  # 피처 이름 리스트
#      18                            target_name='PassOrFail',            # 타깃 변수 이름
#      19                            class_names=['Fail', 'Pass'])        # 클래스 이름 (타깃 값 0, 1에 해당)
#      21 # SVG 객체로 렌더링 후, 화면에 표시하거나 파일로 저장
#      22 v = viz_model.view()     # SVG 객체 생성
#
# AttributeError: module 'dtreeviz' has no attribute 'model'

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/labeled_data.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7996 entries, 0 to 7995
# Data columns (total 45 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   _id                       7996 non-null   object
#  1   TimeStamp                 7996 non-null   object
#  2   PART_FACT_PLAN_DATE       7996 non-null   object
#  3   PART_FACT_SERIAL          7996 non-null   int64
#  4   PART_NAME                 7996 non-null   object
#  5   EQUIP_CD                  7996 non-null   object
#  6   EQUIP_NAME                7996 non-null   object
#  7   PassOrFail                7996 non-null   object
#  8   Reason                    71 non-null     object
#  9   Injection_Time            7996 non-null   float64
#  10  Filling_Time              7996 non-null   float64
#  11  Plasticizing_Time         7996 non-null   float64
#  12  Cycle_Time                7996 non-null   float64
#  13  Clamp_Close_Time          7996 non-null   float64
#  14  Cushion_Position          7996 non-null   float64
#  15  Switch_Over_Position      7996 non-null   float64
#  16  Plasticizing_Position     7996 non-null   float64
#  17  Clamp_Open_Position       7996 non-null   float64
#  18  Max_Injection_Speed       7996 non-null   float64
#  19  Max_Screw_RPM             7996 non-null   float64
#  20  Average_Screw_RPM         7996 non-null   float64
#  21  Max_Injection_Pressure    7996 non-null   float64
#  22  Max_Switch_Over_Pressure  7996 non-null   float64
#  23  Max_Back_Pressure         7996 non-null   float64
#  24  Average_Back_Pressure     7996 non-null   float64
#  25  Barrel_Temperature_1      7996 non-null   float64
#  26  Barrel_Temperature_2      7996 non-null   float64
#  27  Barrel_Temperature_3      7996 non-null   float64
#  28  Barrel_Temperature_4      7996 non-null   float64
#  29  Barrel_Temperature_5      7996 non-null   float64
#  30  Barrel_Temperature_6      7996 non-null   float64
#  31  Barrel_Temperature_7      7996 non-null   float64
#  32  Hopper_Temperature        7996 non-null   float64
#  33  Mold_Temperature_1        7996 non-null   float64
#  34  Mold_Temperature_2        7996 non-null   float64
#  35  Mold_Temperature_3        7996 non-null   float64
#  36  Mold_Temperature_4        7996 non-null   float64
#  37  Mold_Temperature_5        7996 non-null   float64
#  38  Mold_Temperature_6        7996 non-null   float64
#  39  Mold_Temperature_7        7996 non-null   float64
#  40  Mold_Temperature_8        7996 non-null   float64
#  41  Mold_Temperature_9        7996 non-null   float64
#  42  Mold_Temperature_10       7996 non-null   float64
#  43  Mold_Temperature_11       7996 non-null   float64
#  44  Mold_Temperature_12       7996 non-null   float64
# dtypes: float64(36), int64(1), object(8)
# memory usage: 2.7+ MB

# %%
df["PART_NAME"].value_counts()
# Out:
# PART_NAME
# CN7 W/S SIDE MLD'G RH        3371
# CN7 W/S SIDE MLD'G LH        3365
# RG3 MOLD'G W/SHLD, LH         628
# RG3 MOLD'G W/SHLD, RH         628
# SP2 CVR ROOF RACK CTR, RH       2
# JX1 W/S SIDE MLD'G RH           2
# Name: count, dtype: int64
